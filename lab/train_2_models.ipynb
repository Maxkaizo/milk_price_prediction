# %% [markdown]
# # train 2 models
# milk_price_prediction/notebooks/01_train_model_selection.ipynb
#
# ✅ Objective: Load the preprocessed full dataset and train two models:
# - XGBoost with Hyperopt
# - Random Forest with Hyperopt
# Then compare their performance (RMSE) and decide which one should be promoted.

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import root_mean_squared_error
from sklearn.model_selection import cross_val_score
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
import joblib
# Out:
# /home/maxkaizo/.local/share/virtualenvs/milk_price_prediction-mju8LJeN/lib/python3.12/site-packages/hyperopt/atpe.py:19: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
# --- 1. Load data ---
df = pd.read_parquet("../data/processed/full_dataset.parquet")
df = df.dropna(subset=["Precio", "Precio_lag1", "Precio_mean7"])

# %%
df
# Out:
#            Fecha           Estado          Ciudad               Tipo  \
# 1     2024-01-31  Aguascalientes   Aguascalientes       Pasteurizada
# 2     2024-02-02  Aguascalientes   Aguascalientes       Pasteurizada
# 3     2024-02-07  Aguascalientes   Aguascalientes       Pasteurizada
# 4     2024-02-09  Aguascalientes   Aguascalientes       Pasteurizada
# 5     2024-02-12  Aguascalientes   Aguascalientes       Pasteurizada
# ...          ...              ...             ...                ...
# 42138 2025-07-21        Zacatecas       Zacatecas  Ultrapasteurizada
# 42139 2025-07-23        Zacatecas       Zacatecas  Ultrapasteurizada
# 42140 2025-07-25        Zacatecas       Zacatecas  Ultrapasteurizada
# 42141 2025-07-28        Zacatecas       Zacatecas  Ultrapasteurizada
# 42142 2025-07-30        Zacatecas       Zacatecas  Ultrapasteurizada
#
#                Canal  Precio   año  mes  dia dia_semana  Precio_lag1  \
# 1      Autoservicios   23.62  2024    1   31  Wednesday        23.62
# 2      Autoservicios   23.62  2024    2    2     Friday        23.62
# 3      Autoservicios   23.62  2024    2    7  Wednesday        23.62
# 4      Autoservicios   24.15  2024    2    9     Friday        23.62
# 5      Autoservicios   24.15  2024    2   12     Monday        24.15
# ...              ...     ...   ...  ...  ...        ...          ...
# 42138        Tiendas   33.50  2025    7   21     Monday        33.50
# 42139        Tiendas   33.50  2025    7   23  Wednesday        33.50
# 42140        Tiendas   33.50  2025    7   25     Friday        33.50
# 42141        Tiendas   33.50  2025    7   28     Monday        33.50
# 42142        Tiendas   33.50  2025    7   30  Wednesday        33.50
#
#        Precio_mean7
# 1         23.620000
# 2         23.620000
# 3         23.620000
# 4         23.726000
# 5         23.796667
# ...             ...
# 42138     33.500000
# 42139     33.500000
# 42140     33.500000
# 42141     33.500000
# 42142     33.500000
#
# [41954 rows x 12 columns]

# %%
# --- 2. Feature preparation ---
categorical = ["Estado", "Ciudad", "Tipo", "Canal", "dia_semana"]
numerical = ["Precio_lag1", "Precio_mean7", "mes", "dia", "año"]
df[categorical] = df[categorical].astype(str)

# %%
# Convert to dictionaries and vectorize
feature_dicts = df[categorical + numerical].to_dict(orient="records")
dv = DictVectorizer()
X = dv.fit_transform(feature_dicts)
y = df["Precio"].values

# %%
# --- 3. Define objective functions ---
def objective_xgb(params):
    model = XGBRegressor(
        max_depth=int(params["max_depth"]),
        learning_rate=params["learning_rate"],
        n_estimators=int(params["n_estimators"]),
        min_child_weight=params["min_child_weight"],
        gamma=params["gamma"],
        subsample=params["subsample"],
        colsample_bytree=params["colsample_bytree"],
        random_state=42,
        n_jobs=-1
    )
    score = cross_val_score(model, X, y, scoring="neg_root_mean_squared_error", cv=3)
    return {"loss": -score.mean(), "status": STATUS_OK}

# %%
def objective_rf(params):
    model = RandomForestRegressor(
        n_estimators=int(params["n_estimators"]),
        max_depth=int(params["max_depth"]),
        min_samples_split=int(params["min_samples_split"]),
        min_samples_leaf=int(params["min_samples_leaf"]),
        max_features=params["max_features"],
        random_state=42,
        n_jobs=-1
    )
    score = cross_val_score(model, X, y, scoring="neg_root_mean_squared_error", cv=3)
    return {"loss": -score.mean(), "status": STATUS_OK}

# %%
# --- 4. Define search spaces ---
search_space_xgb = {
    "max_depth": hp.quniform("max_depth", 3, 10, 1),
    "learning_rate": hp.loguniform("learning_rate", -4, 0),
    "n_estimators": hp.quniform("n_estimators", 50, 300, 10),
    "min_child_weight": hp.quniform("min_child_weight", 1, 10, 1),
    "gamma": hp.uniform("gamma", 0, 1),
    "subsample": hp.uniform("subsample", 0.5, 1.0),
    "colsample_bytree": hp.uniform("colsample_bytree", 0.5, 1.0),
}

# %%
search_space_rf = {
    "n_estimators": hp.quniform("n_estimators", 50, 300, 10),
    "max_depth": hp.quniform("max_depth", 5, 20, 1),
    "min_samples_split": hp.quniform("min_samples_split", 2, 10, 1),
    "min_samples_leaf": hp.quniform("min_samples_leaf", 1, 5, 1),
    "max_features": hp.choice("max_features", ["sqrt", "log2"]),
}

# %%
# --- 5. Run optimizations ---
trials_xgb = Trials()
best_xgb = fmin(fn=objective_xgb, space=search_space_xgb, algo=tpe.suggest, max_evals=25, trials=trials_xgb)

trials_rf = Trials()
best_rf = fmin(fn=objective_rf, space=search_space_rf, algo=tpe.suggest, max_evals=25, trials=trials_rf)
# Out:
# 100%|██████████| 25/25 [00:11<00:00,  2.24trial/s, best loss: 2.022260687576108]
# 100%|██████████| 25/25 [03:00<00:00,  7.21s/trial, best loss: 2.5678998580695773]

# %%
# --- 6. Retrain best models ---
final_xgb = XGBRegressor(
    max_depth=int(best_xgb["max_depth"]),
    learning_rate=best_xgb["learning_rate"],
    n_estimators=int(best_xgb["n_estimators"]),
    min_child_weight=best_xgb["min_child_weight"],
    gamma=best_xgb["gamma"],
    subsample=best_xgb["subsample"],
    colsample_bytree=best_xgb["colsample_bytree"],
    random_state=42,
    n_jobs=-1
)
final_xgb.fit(X, y)
y_pred_xgb = final_xgb.predict(X)
rmse_xgb = root_mean_squared_error(y, y_pred_xgb)

# %%
final_rf = RandomForestRegressor(
    n_estimators=int(best_rf["n_estimators"]),
    max_depth=int(best_rf["max_depth"]),
    min_samples_split=int(best_rf["min_samples_split"]),
    min_samples_leaf=int(best_rf["min_samples_leaf"]),
    max_features=["sqrt", "log2"][best_rf["max_features"]],
    random_state=42,
    n_jobs=-1
)
final_rf.fit(X, y)
y_pred_rf = final_rf.predict(X)
rmse_rf = root_mean_squared_error(y, y_pred_rf)

# %%
# --- 7. Compare and save models ---
print("\nRMSE XGBoost:", round(rmse_xgb, 4))
print("RMSE Random Forest:", round(rmse_rf, 4))

best_model_name = "XGBoost" if rmse_xgb < rmse_rf else "RandomForest"
print(f"\n✨ Best model: {best_model_name}")
# Out:
# RMSE XGBoost: 0.3061
# RMSE Random Forest: 0.3639
#
# ✨ Best model: XGBoost

# %% [markdown]
# # Olvidé armar el pipeline, a continuación se ajusta y se separa por modelo

# %%
# milk_price_prediction/notebooks/01_train_model_selection.ipynb

# ✅ Objective: Load the preprocessed full dataset and train an XGBoost model with Hyperopt,
# using a pipeline to persist the vectorizer and reuse it later during inference.

import pandas as pd
import numpy as np
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import root_mean_squared_error
from sklearn.model_selection import cross_val_score
from xgboost import XGBRegressor
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.pipeline import Pipeline
import joblib

# --- 1. Load data ---
df = pd.read_parquet("../data/processed/full_dataset.parquet")
df = df.dropna(subset=["Precio", "Precio_lag1", "Precio_mean7"])

# --- 2. Feature preparation ---
categorical = ["Estado", "Ciudad", "Tipo", "Canal", "dia_semana"]
numerical = ["Precio_lag1", "Precio_mean7", "mes", "dia", "año"]
df[categorical] = df[categorical].astype(str)

feature_dicts = df[categorical + numerical].to_dict(orient="records")
y = df["Precio"].values

# --- 3. Define objective function ---
def objective_xgb(params):
    pipeline = Pipeline([
        ("vectorizer", DictVectorizer()),
        ("regressor", XGBRegressor(
            max_depth=int(params["max_depth"]),
            learning_rate=params["learning_rate"],
            n_estimators=int(params["n_estimators"]),
            min_child_weight=params["min_child_weight"],
            gamma=params["gamma"],
            subsample=params["subsample"],
            colsample_bytree=params["colsample_bytree"],
            random_state=42,
            n_jobs=-1
        ))
    ])
    score = cross_val_score(pipeline, feature_dicts, y, scoring="neg_root_mean_squared_error", cv=3)
    return {"loss": -score.mean(), "status": STATUS_OK}

# --- 4. Define search space ---
search_space_xgb = {
    "max_depth": hp.quniform("max_depth", 3, 10, 1),
    "learning_rate": hp.loguniform("learning_rate", -4, 0),
    "n_estimators": hp.quniform("n_estimators", 50, 300, 10),
    "min_child_weight": hp.quniform("min_child_weight", 1, 10, 1),
    "gamma": hp.uniform("gamma", 0, 1),
    "subsample": hp.uniform("subsample", 0.5, 1.0),
    "colsample_bytree": hp.uniform("colsample_bytree", 0.5, 1.0),
}

# --- 5. Run optimization ---
trials_xgb = Trials()
best_xgb = fmin(fn=objective_xgb, space=search_space_xgb, algo=tpe.suggest, max_evals=25, trials=trials_xgb)

# --- 6. Retrain best model with full data ---
dv = DictVectorizer()
X = dv.fit_transform(feature_dicts)

final_xgb = XGBRegressor(
    max_depth=int(best_xgb["max_depth"]),
    learning_rate=best_xgb["learning_rate"],
    n_estimators=int(best_xgb["n_estimators"]),
    min_child_weight=best_xgb["min_child_weight"],
    gamma=best_xgb["gamma"],
    subsample=best_xgb["subsample"],
    colsample_bytree=best_xgb["colsample_bytree"],
    random_state=42,
    n_jobs=-1
)
final_xgb.fit(X, y)
y_pred = final_xgb.predict(X)
rmse = root_mean_squared_error(y, y_pred)
print(f"✅ Final RMSE XGBoost: {rmse:.4f}")

# --- 7. Save artifacts ---
joblib.dump(final_xgb, "models/xgb_model.pkl")
joblib.dump(dv, "models/dv.pkl")
# Out:
# 100%|██████████| 25/25 [00:23<00:00,  1.06trial/s, best loss: 2.0443562515608567]
# ✅ Final RMSE XGBoost: 0.3021
# ['models/dv.pkl']

# %% [markdown]
# success, now lets introduce mlflow

# %%
# milk_price_prediction/notebooks/01_train_model_selection.ipynb

# ✅ Objective: Load the preprocessed full dataset and train an XGBoost model with Hyperopt,
# using a pipeline to persist the vectorizer and reuse it later during inference. Track training with MLflow.

import pandas as pd
import numpy as np
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import root_mean_squared_error
from sklearn.model_selection import cross_val_score
from xgboost import XGBRegressor
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.pipeline import Pipeline
import mlflow
import mlflow.sklearn
from datetime import datetime

# --- 1. Load data ---
df = pd.read_parquet("../data/processed/full_dataset.parquet")
df = df.dropna(subset=["Precio", "Precio_lag1", "Precio_mean7"])

# --- 2. Feature preparation ---
categorical = ["Estado", "Ciudad", "Tipo", "Canal", "dia_semana"]
numerical = ["Precio_lag1", "Precio_mean7", "mes", "dia", "año"]
df[categorical] = df[categorical].astype(str)

feature_dicts = df[categorical + numerical].to_dict(orient="records")
y = df["Precio"].values

# --- 3. Define objective function ---
def objective_xgb(params):
    with mlflow.start_run(nested=True):
        mlflow.log_params(params)

        pipeline = Pipeline([
            ("vectorizer", DictVectorizer()),
            ("regressor", XGBRegressor(
                max_depth=int(params["max_depth"]),
                learning_rate=params["learning_rate"],
                n_estimators=int(params["n_estimators"]),
                min_child_weight=params["min_child_weight"],
                gamma=params["gamma"],
                subsample=params["subsample"] ,
                colsample_bytree=params["colsample_bytree"],
                random_state=42,
                n_jobs=-1
            ))
        ])

        score = cross_val_score(pipeline, feature_dicts, y, scoring="neg_root_mean_squared_error", cv=3)
        rmse = -score.mean()
        mlflow.log_metric("rmse", rmse)
        return {"loss": rmse, "status": STATUS_OK}

# --- 4. Define search space ---
search_space_xgb = {
    "max_depth": hp.quniform("max_depth", 3, 10, 1),
    "learning_rate": hp.loguniform("learning_rate", -4, 0),
    "n_estimators": hp.quniform("n_estimators", 50, 300, 10),
    "min_child_weight": hp.quniform("min_child_weight", 1, 10, 1),
    "gamma": hp.uniform("gamma", 0, 1),
    "subsample": hp.uniform("subsample", 0.5, 1.0),
    "colsample_bytree": hp.uniform("colsample_bytree", 0.5, 1.0),
}

# --- 5. Run optimization ---
mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment("milk-price-xgboost-pipeline")

run_date = datetime.today()
run_name = f"xgb-milk-predictor-{run_date.year}-{run_date.month:02d}"

with mlflow.start_run(run_name=run_name) as run:
    trials_xgb = Trials()
    best_xgb = fmin(fn=objective_xgb, space=search_space_xgb, algo=tpe.suggest, max_evals=25, trials=trials_xgb)

    # --- 6. Retrain best model with full data ---
    dv = DictVectorizer()
    X = dv.fit_transform(feature_dicts)

    final_xgb = XGBRegressor(
        max_depth=int(best_xgb["max_depth"]),
        learning_rate=best_xgb["learning_rate"],
        n_estimators=int(best_xgb["n_estimators"]),
        min_child_weight=best_xgb["min_child_weight"],
        gamma=best_xgb["gamma"],
        subsample=best_xgb["subsample"],
        colsample_bytree=best_xgb["colsample_bytree"],
        random_state=42,
        n_jobs=-1
    )

    pipeline = Pipeline([
        ("vectorizer", dv),
        ("regressor", final_xgb)
    ])
    pipeline.fit(feature_dicts, y)
    y_pred = pipeline.predict(feature_dicts)
    rmse = root_mean_squared_error(y, y_pred)

    mlflow.log_metric("final_rmse", rmse)
    mlflow.sklearn.log_model(pipeline, artifact_path="model")

    print(f"✅ Final RMSE XGBoost: {rmse:.4f}")
    print(f"📌 Model logged to MLflow with run ID: {run.info.run_id}")
# Out:
# 🏃 View run gaudy-dolphin-923 at: http://127.0.0.1:5000/#/experiments/1/runs/821e7f3eb5964e3aba57a78a585b0d9f
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run shivering-carp-496 at: http://127.0.0.1:5000/#/experiments/1/runs/3630c5c93cea4e0f9166cd4a3abcd853
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run secretive-jay-377 at: http://127.0.0.1:5000/#/experiments/1/runs/f26d3ea6b48e4e4791070adb91e04525
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run selective-ox-970 at: http://127.0.0.1:5000/#/experiments/1/runs/b355825621b9436e8a1fed64290746b0
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run valuable-duck-364 at: http://127.0.0.1:5000/#/experiments/1/runs/f14d6b52df084e24b86f6ac34544870b
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run blushing-jay-347 at: http://127.0.0.1:5000/#/experiments/1/runs/b7865bd273d644c39ddd8819ec86de93
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run delightful-yak-774 at: http://127.0.0.1:5000/#/experiments/1/runs/e940f0d2de6d471fa8086520b6c5054d
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run melodic-stork-358 at: http://127.0.0.1:5000/#/experiments/1/runs/404a3a33da3546679e93ea549ed8a04d
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run kindly-penguin-24 at: http://127.0.0.1:5000/#/experiments/1/runs/a9cf7c87bf234d97976df60d854b15bb
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run chill-moose-366 at: http://127.0.0.1:5000/#/experiments/1/runs/4a79e7dbffa841b781468edb4e964fa8
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run delightful-yak-517 at: http://127.0.0.1:5000/#/experiments/1/runs/ba2fd3d7482e405bb1b6ec72ddca3d8f
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run upbeat-dog-733 at: http://127.0.0.1:5000/#/experiments/1/runs/34a0644d449d40a7a156aa5781aa5d54
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run secretive-cow-9 at: http://127.0.0.1:5000/#/experiments/1/runs/4ca46f83e06f4c788ed8f22635e429ea
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run charming-moth-575 at: http://127.0.0.1:5000/#/experiments/1/runs/adef97d71a354c2c9aed5a5c56f54dba
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run delightful-ram-825 at: http://127.0.0.1:5000/#/experiments/1/runs/86dbd03d575d4f54a47f281f506f9f96
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run learned-horse-595 at: http://127.0.0.1:5000/#/experiments/1/runs/0f53adcad0b647e48500786fbfb1a72d
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run bittersweet-mole-530 at: http://127.0.0.1:5000/#/experiments/1/runs/e11f7d8f584847db96578858fdb47226
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run sassy-cow-178 at: http://127.0.0.1:5000/#/experiments/1/runs/e18bbd2fc49c494586f1d183d20bb414
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run serious-shoat-213 at: http://127.0.0.1:5000/#/experiments/1/runs/5232645a2eac4fa6aaf18d57fac27bc2
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run bald-shark-714 at: http://127.0.0.1:5000/#/experiments/1/runs/9dcccc9e7ed64d41a2fa20a92f117fe7
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run capable-moth-408 at: http://127.0.0.1:5000/#/experiments/1/runs/dcff6b6083d24fde87957868ac0166ae
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run able-pig-722 at: http://127.0.0.1:5000/#/experiments/1/runs/6a184c098b1543bea53b82a65fc1b6b4
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run bald-asp-675 at: http://127.0.0.1:5000/#/experiments/1/runs/0842c80868714dde83b7e403f7f55c5c
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run able-cow-556 at: http://127.0.0.1:5000/#/experiments/1/runs/0de8d975791240a6800fb39b265607f8
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run sassy-grub-232 at: http://127.0.0.1:5000/#/experiments/1/runs/af52305e1e2248d7a355a6447af368a3
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 100%|██████████| 25/25 [00:30<00:00,  1.24s/trial, best loss: 2.043419080429148]
# 2025/07/31 11:21:26 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/07/31 11:21:32 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# ✅ Final RMSE XGBoost: 0.3000
# 📌 Model logged to MLflow with run ID: 2db6aa866e2740749b9f45262f4f2f18
# 🏃 View run xgb-milk-predictor-2025-07 at: http://127.0.0.1:5000/#/experiments/1/runs/2db6aa866e2740749b9f45262f4f2f18
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1

# %% [markdown]
# olvidé el registro, ahora va completo

# %%
# milk_price_prediction/notebooks/01_train_model_selection.ipynb

# ✅ Objective: Load the preprocessed full dataset and train an XGBoost model with Hyperopt,
# using a pipeline to persist the vectorizer and reuse it later during inference. Track training with MLflow.

import pandas as pd
import numpy as np
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import root_mean_squared_error
from sklearn.model_selection import cross_val_score
from xgboost import XGBRegressor
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.pipeline import Pipeline
import mlflow
import mlflow.sklearn
from datetime import datetime

# --- 1. Load data ---
df = pd.read_parquet("../data/processed/full_dataset.parquet")
df = df.dropna(subset=["Precio", "Precio_lag1", "Precio_mean7"])

# --- 2. Feature preparation ---
categorical = ["Estado", "Ciudad", "Tipo", "Canal", "dia_semana"]
numerical = ["Precio_lag1", "Precio_mean7", "mes", "dia", "año"]
df[categorical] = df[categorical].astype(str)

feature_dicts = df[categorical + numerical].to_dict(orient="records")
y = df["Precio"].values

# --- 3. Define objective function ---
def objective_xgb(params):
    with mlflow.start_run(nested=True):
        mlflow.log_params(params)

        pipeline = Pipeline([
            ("vectorizer", DictVectorizer()),
            ("regressor", XGBRegressor(
                max_depth=int(params["max_depth"]),
                learning_rate=params["learning_rate"],
                n_estimators=int(params["n_estimators"]),
                min_child_weight=params["min_child_weight"],
                gamma=params["gamma"],
                subsample=params["subsample"] ,
                colsample_bytree=params["colsample_bytree"],
                random_state=42,
                n_jobs=-1
            ))
        ])

        score = cross_val_score(pipeline, feature_dicts, y, scoring="neg_root_mean_squared_error", cv=3)
        rmse = -score.mean()
        mlflow.log_metric("rmse", rmse)
        return {"loss": rmse, "status": STATUS_OK}

# --- 4. Define search space ---
search_space_xgb = {
    "max_depth": hp.quniform("max_depth", 3, 10, 1),
    "learning_rate": hp.loguniform("learning_rate", -4, 0),
    "n_estimators": hp.quniform("n_estimators", 50, 300, 10),
    "min_child_weight": hp.quniform("min_child_weight", 1, 10, 1),
    "gamma": hp.uniform("gamma", 0, 1),
    "subsample": hp.uniform("subsample", 0.5, 1.0),
    "colsample_bytree": hp.uniform("colsample_bytree", 0.5, 1.0),
}

# --- 5. Run optimization ---
mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment("milk-price-xgboost-pipeline")

run_date = datetime.today()
run_name = f"xgb-milk-predictor-{run_date.year}-{run_date.month:02d}"
model_name = "milk-price-predictor"

with mlflow.start_run(run_name=run_name) as run:
    trials_xgb = Trials()
    best_xgb = fmin(fn=objective_xgb, space=search_space_xgb, algo=tpe.suggest, max_evals=25, trials=trials_xgb)

    # --- 6. Retrain best model with full data ---
    dv = DictVectorizer()
    X = dv.fit_transform(feature_dicts)

    final_xgb = XGBRegressor(
        max_depth=int(best_xgb["max_depth"]),
        learning_rate=best_xgb["learning_rate"],
        n_estimators=int(best_xgb["n_estimators"]),
        min_child_weight=best_xgb["min_child_weight"],
        gamma=best_xgb["gamma"],
        subsample=best_xgb["subsample"],
        colsample_bytree=best_xgb["colsample_bytree"],
        random_state=42,
        n_jobs=-1
    )

    pipeline = Pipeline([
        ("vectorizer", dv),
        ("regressor", final_xgb)
    ])
    pipeline.fit(feature_dicts, y)
    y_pred = pipeline.predict(feature_dicts)
    rmse = root_mean_squared_error(y, y_pred)

    mlflow.log_metric("final_rmse", rmse)
    mlflow.sklearn.log_model(pipeline, artifact_path="model")

    # --- 7. Register model ---
    run_id = run.info.run_id
    model_uri = f"runs:/{run_id}/model"
    mlflow.register_model(model_uri=model_uri, name=model_name)

    print(f"✅ Final RMSE XGBoost: {rmse:.4f}")
    print(f"📌 Model logged to MLflow with run ID: {run_id}")
    print(f"📌 Model registered in MLflow Model Registry as '{model_name}'")
# Out:
# 🏃 View run nimble-steed-808 at: http://127.0.0.1:5000/#/experiments/1/runs/1911b05b0903441b8b8c38bf0974ce07
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run puzzled-lynx-927 at: http://127.0.0.1:5000/#/experiments/1/runs/4362167cad1741309385121aaef3c763
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run marvelous-wolf-885 at: http://127.0.0.1:5000/#/experiments/1/runs/509f1c528233450d9275041aa2ec7791
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run learned-asp-598 at: http://127.0.0.1:5000/#/experiments/1/runs/09f39f3698f64112ba8aaa104898a84e
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run ambitious-croc-870 at: http://127.0.0.1:5000/#/experiments/1/runs/0ff11bff129345a79fc3fbfef72ee1a4
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run masked-kite-811 at: http://127.0.0.1:5000/#/experiments/1/runs/74173e29cac44a3aa8f81f1589603bca
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run adorable-koi-857 at: http://127.0.0.1:5000/#/experiments/1/runs/97b552634cb84838ab228bd0d783ac42
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run placid-mule-205 at: http://127.0.0.1:5000/#/experiments/1/runs/4c715cdaa5034037a094072b058c0e13
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run silent-pug-581 at: http://127.0.0.1:5000/#/experiments/1/runs/cf4736d457de4fceb72a4a207a406d78
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run adorable-conch-900 at: http://127.0.0.1:5000/#/experiments/1/runs/f217b5b99f614e1eaeede37d72f67bb8
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run tasteful-quail-926 at: http://127.0.0.1:5000/#/experiments/1/runs/6f45412443de4736bf003936e2e8bded
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run traveling-sponge-752 at: http://127.0.0.1:5000/#/experiments/1/runs/5713b8a5580d4de0958d80da8d6f23a1
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run able-trout-286 at: http://127.0.0.1:5000/#/experiments/1/runs/9be4cf4508d747aa95f690d28ce8bf8a
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run sneaky-rat-277 at: http://127.0.0.1:5000/#/experiments/1/runs/6f25e457ba414d16a7fe8192cddfafb8
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run sassy-chimp-433 at: http://127.0.0.1:5000/#/experiments/1/runs/ed61359358ec4bbdb3f7f11363c71bba
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run funny-eel-399 at: http://127.0.0.1:5000/#/experiments/1/runs/96ed09c75ec344fc8483f155fb192d96
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run polite-fox-595 at: http://127.0.0.1:5000/#/experiments/1/runs/f4d99053066443079de60efe2c02918b
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run luminous-dove-280 at: http://127.0.0.1:5000/#/experiments/1/runs/3fc1db3d217448778d211e851e6e8f9c
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run angry-moose-194 at: http://127.0.0.1:5000/#/experiments/1/runs/7413a8fb0d8c48a3937c1f14868602a9
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run bouncy-hare-285 at: http://127.0.0.1:5000/#/experiments/1/runs/084ca2f4bdd2420eb1011ccbd40c4d1d
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run nervous-snake-696 at: http://127.0.0.1:5000/#/experiments/1/runs/823400cbe05e47d4b7851f6f231dfad5
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run chill-moth-563 at: http://127.0.0.1:5000/#/experiments/1/runs/820f62cf20f741c5a5765abac62a3bb3
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run smiling-shrew-490 at: http://127.0.0.1:5000/#/experiments/1/runs/b19961ac2904409babdd555b580de32a
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run capable-shrimp-255 at: http://127.0.0.1:5000/#/experiments/1/runs/c8ac737f10cb424494f4418413a3442d
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run receptive-cod-251 at: http://127.0.0.1:5000/#/experiments/1/runs/31c2ce5a47764e968d46ffa4b5b61bbb
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 100%|██████████| 25/25 [00:25<00:00,  1.02s/trial, best loss: 2.0479051140362334]
# 2025/07/31 11:26:23 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/07/31 11:26:28 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Registered model 'milk-price-predictor' already exists. Creating a new version of this model...
# 2025/07/31 11:26:31 WARNING mlflow.tracking._model_registry.fluent: Run with id 9d9704f49df14c4db307fd5552dbf298 has no artifacts at artifact path 'model', registering model based on models:/m-1ff549d75d2d452f804dfaf4ca1d1182 instead
# 2025/07/31 11:26:31 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: milk-price-predictor, version 38
# ✅ Final RMSE XGBoost: 0.2909
# 📌 Model logged to MLflow with run ID: 9d9704f49df14c4db307fd5552dbf298
# 📌 Model registered in MLflow Model Registry as 'milk-price-predictor'
# 🏃 View run xgb-milk-predictor-2025-07 at: http://127.0.0.1:5000/#/experiments/1/runs/9d9704f49df14c4db307fd5552dbf298
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# Created version '38' of model 'milk-price-predictor'.

# %% [markdown]
# cambié la estructura en mlflow para tener dos modelos, y un solo experimento, posterior se relizará la evaluación y selección para promoción

# %% [markdown]
# # Entrenamiento de modelo xgboost funcionando correctamente con:
#
# * actualización de registros diarios
# * features adicionales
# * optimización de parametros con hyperopt
# * tracking con mlflow
# * registro de modelo en s3

# %%
# milk_price_prediction/notebooks/01_train_model_selection.ipynb

# ✅ Objective: Load the preprocessed full dataset and train an XGBoost model with Hyperopt,
# using a pipeline to persist the vectorizer and reuse it later during inference. Track training with MLflow.

import pandas as pd
import numpy as np
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import root_mean_squared_error
from sklearn.model_selection import cross_val_score
from xgboost import XGBRegressor
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.pipeline import Pipeline
import mlflow
import mlflow.sklearn
from datetime import datetime

# --- 1. Load data ---
df = pd.read_parquet("../data/processed/full_dataset.parquet")
df = df.dropna(subset=["Precio", "Precio_lag1", "Precio_mean7"])

# --- 2. Feature preparation ---
categorical = ["Estado", "Ciudad", "Tipo", "Canal", "dia_semana"]
numerical = ["Precio_lag1", "Precio_mean7", "mes", "dia", "año"]
df[categorical] = df[categorical].astype(str)

feature_dicts = df[categorical + numerical].to_dict(orient="records")
y = df["Precio"].values

# --- 3. Define objective function ---
def objective_xgb(params):
    with mlflow.start_run(nested=True):
        mlflow.log_params(params)
        mlflow.set_tags({"model_type": "xgboost"})

        pipeline = Pipeline([
            ("vectorizer", DictVectorizer()),
            ("regressor", XGBRegressor(
                max_depth=int(params["max_depth"]),
                learning_rate=params["learning_rate"],
                n_estimators=int(params["n_estimators"]),
                min_child_weight=params["min_child_weight"],
                gamma=params["gamma"],
                subsample=params["subsample"] ,
                colsample_bytree=params["colsample_bytree"],
                random_state=42,
                n_jobs=-1
            ))
        ])

        score = cross_val_score(pipeline, feature_dicts, y, scoring="neg_root_mean_squared_error", cv=3)
        rmse = -score.mean()
        mlflow.log_metric("rmse", rmse)
        return {"loss": rmse, "status": STATUS_OK}

# --- 4. Define search space ---
search_space_xgb = {
    "max_depth": hp.quniform("max_depth", 3, 10, 1),
    "learning_rate": hp.loguniform("learning_rate", -4, 0),
    "n_estimators": hp.quniform("n_estimators", 50, 300, 10),
    "min_child_weight": hp.quniform("min_child_weight", 1, 10, 1),
    "gamma": hp.uniform("gamma", 0, 1),
    "subsample": hp.uniform("subsample", 0.5, 1.0),
    "colsample_bytree": hp.uniform("colsample_bytree", 0.5, 1.0),
}

# --- 5. Run optimization ---
mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment("milk-price-predictor")

run_date = datetime.today()
run_name = f"xgb-milk-predictor-{run_date.year}-{run_date.month:02d}"
model_name = "milk-price-predictor-xgb"

with mlflow.start_run(run_name=run_name) as run:
    trials_xgb = Trials()
    best_xgb = fmin(fn=objective_xgb, space=search_space_xgb, algo=tpe.suggest, max_evals=25, trials=trials_xgb)

    # --- 6. Retrain best model with full data ---
    dv = DictVectorizer()
    X = dv.fit_transform(feature_dicts)

    final_xgb = XGBRegressor(
        max_depth=int(best_xgb["max_depth"]),
        learning_rate=best_xgb["learning_rate"],
        n_estimators=int(best_xgb["n_estimators"]),
        min_child_weight=best_xgb["min_child_weight"],
        gamma=best_xgb["gamma"],
        subsample=best_xgb["subsample"],
        colsample_bytree=best_xgb["colsample_bytree"],
        random_state=42,
        n_jobs=-1
    )

    pipeline = Pipeline([
        ("vectorizer", dv),
        ("regressor", final_xgb)
    ])
    pipeline.fit(feature_dicts, y)
    y_pred = pipeline.predict(feature_dicts)
    rmse = root_mean_squared_error(y, y_pred)

    mlflow.log_metric("final_rmse", rmse)
    mlflow.set_tags({"model_type": "xgboost"})
    mlflow.sklearn.log_model(pipeline, artifact_path="model")

    # --- 7. Register model ---
    run_id = run.info.run_id
    model_uri = f"runs:/{run_id}/model"
    mlflow.register_model(model_uri=model_uri, name=model_name)

    print(f"✅ Final RMSE XGBoost: {rmse:.4f}")
    print(f"📌 Model logged to MLflow with run ID: {run_id}")
    print(f"📌 Model registered in MLflow Model Registry as '{model_name}'")
# Out:
# 2025/07/31 11:32:58 INFO mlflow.tracking.fluent: Experiment with name 'milk-price-predictor' does not exist. Creating a new experiment.
# 🏃 View run vaunted-asp-689 at: http://127.0.0.1:5000/#/experiments/2/runs/501ce85d9a49415ea45ccf5ec99f86d8
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run handsome-croc-722 at: http://127.0.0.1:5000/#/experiments/2/runs/66583bec62334981b9f2ce3dc768c9c1
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run unruly-gnat-376 at: http://127.0.0.1:5000/#/experiments/2/runs/2d64281bb73b4216826888ce7acc6da2
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run caring-sheep-22 at: http://127.0.0.1:5000/#/experiments/2/runs/7ab574de74fa4deb899afebf53bd732c
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run big-moth-435 at: http://127.0.0.1:5000/#/experiments/2/runs/264dc294775d4d42b15f76add70e6f83
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run fortunate-perch-756 at: http://127.0.0.1:5000/#/experiments/2/runs/4296920702454365b3fd9278c16b0346
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run polite-sheep-45 at: http://127.0.0.1:5000/#/experiments/2/runs/f1690b24b23a433bbe749bd058b8dd51
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run exultant-shrew-352 at: http://127.0.0.1:5000/#/experiments/2/runs/119ce05bbc464c4ea735450fc5aca221
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run dashing-fowl-673 at: http://127.0.0.1:5000/#/experiments/2/runs/5fb2548bfaa34a1384468ba574f62054
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run lyrical-grouse-302 at: http://127.0.0.1:5000/#/experiments/2/runs/99c6e0427b9442a186d4141b1940e58e
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run bouncy-conch-833 at: http://127.0.0.1:5000/#/experiments/2/runs/7d1c783b5fbe437ea3ab8ed0126c4055
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run bold-crab-707 at: http://127.0.0.1:5000/#/experiments/2/runs/af272baeea8e4dfab938f2a7c662f19f
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run sedate-crab-367 at: http://127.0.0.1:5000/#/experiments/2/runs/70eb0fa9201c416cb30100c7ebdeaa18
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run industrious-jay-814 at: http://127.0.0.1:5000/#/experiments/2/runs/21cb8732c870401fbcc7e1a079102ea5
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run silent-ray-3 at: http://127.0.0.1:5000/#/experiments/2/runs/a3765a52962b4d7eb412c842e6495a8a
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run peaceful-slug-246 at: http://127.0.0.1:5000/#/experiments/2/runs/2c650c8d31224e40aa24556a3cb49d90
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run tasteful-robin-66 at: http://127.0.0.1:5000/#/experiments/2/runs/e7eea44b102f4b44b3573c8fa31632d0
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run melodic-cod-425 at: http://127.0.0.1:5000/#/experiments/2/runs/e829e3c65911413080e42375d913f918
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run bedecked-mink-568 at: http://127.0.0.1:5000/#/experiments/2/runs/74942cf6b6444090826082f410846f39
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run charming-ox-526 at: http://127.0.0.1:5000/#/experiments/2/runs/36b86b253341412d98ca95233d581863
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run industrious-flea-263 at: http://127.0.0.1:5000/#/experiments/2/runs/4017a53e32b94571b9c8cba5ca1dd9ae
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run brawny-stag-11 at: http://127.0.0.1:5000/#/experiments/2/runs/017920df685d4b939a647365300ffb41
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run rumbling-shrimp-138 at: http://127.0.0.1:5000/#/experiments/2/runs/608a8f5722024008a522bb72902301a2
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run shivering-gnu-20 at: http://127.0.0.1:5000/#/experiments/2/runs/bcb16345a2c84763852b47c07575f672
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run traveling-hog-48 at: http://127.0.0.1:5000/#/experiments/2/runs/688724c189794da6b6401ff9e05e5dab
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 100%|██████████| 25/25 [00:29<00:00,  1.16s/trial, best loss: 2.030909717777823]
# 2025/07/31 11:33:28 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/07/31 11:33:31 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Successfully registered model 'milk-price-predictor-xgb'.
# 2025/07/31 11:33:33 WARNING mlflow.tracking._model_registry.fluent: Run with id 14b70c6581874d61bb95b077cfb88291 has no artifacts at artifact path 'model', registering model based on models:/m-123af597022f4aa1b9b40c8254828368 instead
# 2025/07/31 11:33:33 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: milk-price-predictor-xgb, version 1
# Created version '1' of model 'milk-price-predictor-xgb'.
# ✅ Final RMSE XGBoost: 0.2554
# 📌 Model logged to MLflow with run ID: 14b70c6581874d61bb95b077cfb88291
# 📌 Model registered in MLflow Model Registry as 'milk-price-predictor-xgb'
# 🏃 View run xgb-milk-predictor-2025-07 at: http://127.0.0.1:5000/#/experiments/2/runs/14b70c6581874d61bb95b077cfb88291
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2

# %% [markdown]
# # replica pero con random forest

# %%
# milk_price_prediction/notebooks/01_train_model_selection.ipynb

# ✅ Objective: Load the preprocessed full dataset and train both XGBoost and Random Forest models with Hyperopt,
# using a pipeline to persist the vectorizer and reuse it later during inference. Track training with MLflow.

import pandas as pd
import numpy as np
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import root_mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
import mlflow
import mlflow.sklearn
from datetime import datetime

# --- 1. Load data ---
df = pd.read_parquet("../data/processed/full_dataset.parquet")
df = df.dropna(subset=["Precio", "Precio_lag1", "Precio_mean7"])

# --- 2. Feature preparation ---
categorical = ["Estado", "Ciudad", "Tipo", "Canal", "dia_semana"]
numerical = ["Precio_lag1", "Precio_mean7", "mes", "dia", "año"]
df[categorical] = df[categorical].astype(str)

feature_dicts = df[categorical + numerical].to_dict(orient="records")
y = df["Precio"].values

# --- 3. Define objective function ---
def objective_rf(params):
    with mlflow.start_run(nested=True):
        mlflow.log_params(params)
        mlflow.set_tags({"model_type": "random_forest"})

        pipeline = Pipeline([
            ("vectorizer", DictVectorizer()),
            ("regressor", RandomForestRegressor(
                n_estimators=int(params["n_estimators"]),
                max_depth=int(params["max_depth"]),
                min_samples_split=int(params["min_samples_split"]),
                min_samples_leaf=int(params["min_samples_leaf"]),
                random_state=42,
                n_jobs=-1
            ))
        ])

        score = cross_val_score(pipeline, feature_dicts, y, scoring="neg_root_mean_squared_error", cv=3)
        rmse = -score.mean()
        mlflow.log_metric("rmse", rmse)
        return {"loss": rmse, "status": STATUS_OK}

# --- 4. Define search space ---
search_space_rf = {
    "n_estimators": hp.quniform("n_estimators", 50, 300, 10),
    "max_depth": hp.quniform("max_depth", 5, 20, 1),
    "min_samples_split": hp.quniform("min_samples_split", 2, 10, 1),
    "min_samples_leaf": hp.quniform("min_samples_leaf", 1, 5, 1)
}

# --- 5. Run optimization ---
mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment("milk-price-predictor")

run_date = datetime.today()
run_name = f"rf-milk-predictor-{run_date.year}-{run_date.month:02d}"
model_name = "milk-price-predictor-rf"

with mlflow.start_run(run_name=run_name) as run:
    trials_rf = Trials()
    best_rf = fmin(fn=objective_rf, space=search_space_rf, algo=tpe.suggest, max_evals=25, trials=trials_rf)

    # --- 6. Retrain best model with full data ---
    dv = DictVectorizer()
    X = dv.fit_transform(feature_dicts)

    final_rf = RandomForestRegressor(
        n_estimators=int(best_rf["n_estimators"]),
        max_depth=int(best_rf["max_depth"]),
        min_samples_split=int(best_rf["min_samples_split"]),
        min_samples_leaf=int(best_rf["min_samples_leaf"]),
        random_state=42,
        n_jobs=-1
    )

    pipeline = Pipeline([
        ("vectorizer", dv),
        ("regressor", final_rf)
    ])
    pipeline.fit(feature_dicts, y)
    y_pred = pipeline.predict(feature_dicts)
    rmse = root_mean_squared_error(y, y_pred)

    mlflow.log_metric("final_rmse", rmse)
    mlflow.set_tags({"model_type": "random_forest"})
    mlflow.sklearn.log_model(pipeline, artifact_path="model")

    # --- 7. Register model ---
    run_id = run.info.run_id
    model_uri = f"runs:/{run_id}/model"
    mlflow.register_model(model_uri=model_uri, name=model_name)

    print(f"✅ Final RMSE Random Forest: {rmse:.4f}")
    print(f"📌 Model logged to MLflow with run ID: {run_id}")
    print(f"📌 Model registered in MLflow Model Registry as '{model_name}'")
# Out:
# 🏃 View run sincere-bat-175 at: http://127.0.0.1:5000/#/experiments/2/runs/a93304a78c5c4d928c81036c11c3c989
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run tasteful-cow-840 at: http://127.0.0.1:5000/#/experiments/2/runs/d6e999241e0141c587b8b9bb8fadddf3
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run stately-worm-770 at: http://127.0.0.1:5000/#/experiments/2/runs/0e3e5461b95347b0925496ba469f9e4e
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run sassy-goose-434 at: http://127.0.0.1:5000/#/experiments/2/runs/fba598d8f4da44f1b26db9bfbb5f4d2b
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run defiant-mouse-5 at: http://127.0.0.1:5000/#/experiments/2/runs/1cc741c3a80a44658bb7be32e31d553f
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run rebellious-mule-879 at: http://127.0.0.1:5000/#/experiments/2/runs/68c985a10a88457d90dfd48193e7e78a
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run likeable-colt-734 at: http://127.0.0.1:5000/#/experiments/2/runs/468d0259d21f416f929d68ffad7f5f1f
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run spiffy-goat-316 at: http://127.0.0.1:5000/#/experiments/2/runs/3dc85ed709ed490db00862da643ef805
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run bold-moose-822 at: http://127.0.0.1:5000/#/experiments/2/runs/81991fe271bc4b49907a20dfb006b546
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run bittersweet-goat-965 at: http://127.0.0.1:5000/#/experiments/2/runs/601d84620cbb4d959bc61f8695916f7b
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run ambitious-sloth-63 at: http://127.0.0.1:5000/#/experiments/2/runs/9594a5f4aef74c7cb5f946644fdb0029
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run fun-swan-113 at: http://127.0.0.1:5000/#/experiments/2/runs/405541690ad64fe18db965918c4c1c08
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run likeable-foal-606 at: http://127.0.0.1:5000/#/experiments/2/runs/70dfb238794240c894d7f595f359b37d
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run glamorous-loon-791 at: http://127.0.0.1:5000/#/experiments/2/runs/0a10dd1e0eb14f14a16fe0a1e9a6a325
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run sedate-lynx-283 at: http://127.0.0.1:5000/#/experiments/2/runs/f8b2c22495eb4d009b90505a2f04317a
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run unleashed-elk-19 at: http://127.0.0.1:5000/#/experiments/2/runs/cee2df21c9194a669a0d0019a8480668
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run delicate-skink-996 at: http://127.0.0.1:5000/#/experiments/2/runs/7846666efe6c42ad93b33ab36d65e371
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run unleashed-shark-680 at: http://127.0.0.1:5000/#/experiments/2/runs/1ce61abe1bd84de3bfe1a64e567fe75b
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run receptive-rat-76 at: http://127.0.0.1:5000/#/experiments/2/runs/573ac5995e8f456ba4e11dd4d4ef8f9b
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run shivering-mole-735 at: http://127.0.0.1:5000/#/experiments/2/runs/bf19b209358d47a9b98cbb1f78dcc5fd
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run upset-hog-437 at: http://127.0.0.1:5000/#/experiments/2/runs/d49ad3b5f1ed45829c75a0f5a707eae1
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run loud-bat-888 at: http://127.0.0.1:5000/#/experiments/2/runs/0d9901c208e64569906f6059999bec7c
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run beautiful-hen-433 at: http://127.0.0.1:5000/#/experiments/2/runs/b09ad73982634f6d90df8c9840351402
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run bustling-pig-755 at: http://127.0.0.1:5000/#/experiments/2/runs/c73a95b5123146f4a927289d34752187
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 🏃 View run kindly-dolphin-482 at: http://127.0.0.1:5000/#/experiments/2/runs/d3c41d425781417fbea1e71823c436bc
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
#
# 100%|██████████| 25/25 [09:37<00:00, 23.12s/trial, best loss: 2.0109117986141025]
# 2025/07/31 11:48:54 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/07/31 11:48:58 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Successfully registered model 'milk-price-predictor-rf'.
# 2025/07/31 11:49:01 WARNING mlflow.tracking._model_registry.fluent: Run with id 05870e884bc84f9bb9336cd8044d13f5 has no artifacts at artifact path 'model', registering model based on models:/m-dafd2965ee21488eb1bdb5e5dcce5a06 instead
# 2025/07/31 11:49:01 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: milk-price-predictor-rf, version 1
# ✅ Final RMSE Random Forest: 0.2710
# 📌 Model logged to MLflow with run ID: 05870e884bc84f9bb9336cd8044d13f5
# 📌 Model registered in MLflow Model Registry as 'milk-price-predictor-rf'
# 🏃 View run rf-milk-predictor-2025-07 at: http://127.0.0.1:5000/#/experiments/2/runs/05870e884bc84f9bb9336cd8044d13f5
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# Created version '1' of model 'milk-price-predictor-rf'.
